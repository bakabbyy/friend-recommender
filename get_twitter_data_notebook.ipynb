# %%
# import packages and authorize application
import json
import tweepy
from twitter_creds import *

# pass credentials to authorize Twitter app
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser(), wait_on_rate_limit=True, wait_on_rate_limit_notify=True)

# %%
def user_timeline(user_id):
    """
    Returns ~3000 of the most recent tweets of a specific user's timeline and dumps
    into a JSON file.
    ---
    :param user_id: Unique identifier of the Twitter account to fetch tweets
    :return: JSON file export of tweet contents and metadata
    """
    timeline_tweets = []

    try:
        # make initial request for most recent tweets
        timeline = api.user_timeline(user_id=user_id, count=200)

        # save most recent tweets
        timeline_tweets.extend(timeline)

        # save the id of the oldest tweet less one
        oldest = timeline_tweets[-1]['id'] - 1

        # continue where from the last id until there are no tweets left to collect
        while len(timeline) > 0:
            print(f'getting tweets before {oldest}s')

            # all subsequent requests use the max_id param to prevent duplicates
            timeline = api.user_timeline(user_id=user_id, count=200, max_id=oldest)

            timeline_tweets.extend(timeline)

            oldest = timeline_tweets[-1]['id'] - 1

            print(f'...{len(timeline_tweets)}s tweets downloaded so far')

    except IndexError:
        pass

    # extract fields into a list of dictionaries
    tweets_dict = [{'id': tweet['id'], 'created_at': tweet['created_at'],
                    'screen_name': tweet['user']['screen_name'], 'user_id': tweet['user']['id'],
                    'in_reply_to_status_id': tweet['in_reply_to_status_id'],
                    'in_reply_to_screen_name': tweet['in_reply_to_screen_name'],
                    'in_reply_to_user_id': tweet['in_reply_to_user_id'],
                    'favorite_count': tweet['favorite_count'], 'retweet_count': tweet['retweet_count'],
                    'text': tweet['text']} for tweet in timeline_tweets]

    return tweets_dict


def user_favorites(user_id):
    """
    Returns ~3000 of the most recent tweets that a specific user has favorited
    and dumps into a JSON file.
    ---
    :param user_id: Unique identifier of the Twitter account to fetch tweets
    :return: JSON file export of tweet contents and metadata
    """
    favorite_tweets = []

    try:
        # make initial request for most recent tweets
        favorites = api.favorites(user_id=user_id, count=200)

        # save most recent tweets
        favorite_tweets.extend(favorites)

        # save the id of the oldest tweet less one
        oldest = favorite_tweets[-1]['id'] - 1

        # continue where from the last id until there are no tweets left to collect
        while len(favorites) > 0:
            print(f'getting tweets before {oldest}s')

            # all subsequent requests use the max_id param to prevent duplicates
            favorites = api.favorites(user_id=user_id, count=200, max_id=oldest)

            favorite_tweets.extend(favorites)

            oldest = favorite_tweets[-1]['id'] - 1

            print(f'...{len(favorite_tweets)}s tweets downloaded so far')

    except IndexError:
        pass

    # extract fields into a list of dictionaries
    favorites_dict = [{'favorited_by_id': user_id, 'id': tweet['id'],
                       'created_at': tweet['created_at'],
                       'screen_name': tweet['user']['screen_name'],
                       'user_id': tweet['user']['id'],
                       'in_reply_to_status_id': tweet['in_reply_to_status_id'],
                       'in_reply_to_screen_name': tweet['in_reply_to_screen_name'],
                       'in_reply_to_user_id': tweet['in_reply_to_user_id'],
                       'favorite_count': tweet['favorite_count'],
                       'retweet_count': tweet['retweet_count'],
                       'text': tweet['text']} for tweet in favorite_tweets]

    return favorites_dict


def user_profile(user_id):
    """
    Returns the profile information and friends/followers lists of a specific user.
    ---
    :param user_id: Unique identifier of the Twitter account to information
    :return: JSON file export of tweet contents and metadata
    """
    # get user profile information
    info = api.get_user(user_id=user_id)

    # extract fields into a dictionary
    profile_dict = {'user_id': info['id'], 'screen_name': info['screen_name'],
                    'followers_count': info['followers_count'],
                    'friends_count': info['friends_count'],
                    'favourites_count': info['favourites_count'],
                    'statuses_count': info['statuses_count']}

    # use cursor to page through all friends and create list of friend ids
    all_friends = []
    for friend in tweepy.Cursor(api.friends_ids, user_id=user_id, count=200).pages():
        all_friends.extend(friend['ids'])

    # use cursor to page through all followers and create list of follower ids
    all_followers = []
    for follower in tweepy.Cursor(api.followers_ids, user_id=user_id, count=200).pages():
        all_followers.extend(follower['ids'])

    # add lists of friends and followers ids to user_info dictionary
    profile_dict['follower_ids'] = all_followers
    profile_dict['friend_ids'] = all_friends

    return profile_dict

# %% [markdown]
# ## Create lists using my profile and set chunks to call functions on list of my followers

# %%
# initialize empty containers with host account's info
timelines = [user_timeline(2649540547)]
favorites = [user_favorites(2649540547)]
profiles = [user_profile(2649540547)]
# Out:
# getting tweets before 996060287794008064s
# ...118s tweets downloaded so far
# getting tweets before 1201966032031797247s
# ...389s tweets downloaded so far
# getting tweets before 1187835256738668544s
# ...585s tweets downloaded so far
# getting tweets before 1100819374024388608s
# ...779s tweets downloaded so far
# getting tweets before 978457315094405119s
# ...792s tweets downloaded so far
# getting tweets before 906389562024488959s
# ...798s tweets downloaded so far
# getting tweets before 663089813080248321s
# ...798s tweets downloaded so far

# %%
# create chunks to run API calls
my_followers = profiles[0]['follower_ids']
start, stop = 0, 20
list_segment = my_followers[start:stop]

# %% [markdown]
# ## Timelines loop

# %%
for idx, user_id in enumerate(list_segment):
    try:
        timelines.append(user_timeline(user_id))
        print('Appended {} of {} timelines...'.format(idx+1, len(list_segment)))
    except tweepy.TweepError:
        print("Failed to run the command on that user, Skipping...")

with open(f'timelines_{stop}.json', 'w') as fout:
    json.dump(timelines, fout)

# %% [markdown]
# ## Favorites loop

# %%
for idx, user_id in enumerate(list_segment):
    try:
        favorites.append(user_favorites(user_id))
        print('Appended {} of {} timelines...'.format(idx+1, len(list_segment)))
    except tweepy.TweepError:
        print("Failed to run the command on that user, Skipping...")

with open(f'favorites_{stop}.json', 'w') as fout:
    json.dump(favorites, fout)
# Out:
# getting tweets before 1155288607302623233s
# ...4s tweets downloaded so far
# Appended 1 of 20 timelines...
# getting tweets before 1235237910850330624s
# ...380s tweets downloaded so far
# getting tweets before 1216252085517406207s
# ...553s tweets downloaded so far
# getting tweets before 1139309933495771135s
# ...719s tweets downloaded so far
# getting tweets before 1101230196332478463s
# ...783s tweets downloaded so far
# getting tweets before 399175271091171327s
# ...783s tweets downloaded so far
# Appended 2 of 20 timelines...
# getting tweets before 1233014505434734591s
# ...13s tweets downloaded so far
# Appended 3 of 20 timelines...
# getting tweets before 811415367562072063s
# ...274s tweets downloaded so far
# getting tweets before 630259267287715840s
# ...361s tweets downloaded so far
# getting tweets before 595682539018317824s
# ...496s tweets downloaded so far
# getting tweets before 569630763567575041s
# ...628s tweets downloaded so far
# getting tweets before 550555527164342271s
# ...760s tweets downloaded so far
# getting tweets before 537486771915718655s
# ...873s tweets downloaded so far
# getting tweets before 517848127597199359s
# ...975s tweets downloaded so far
# getting tweets before 493597283674365953s
# ...1071s tweets downloaded so far
# getting tweets before 468448817319124992s
# ...1159s tweets downloaded so far
# getting tweets before 455087971554045951s
# ...1250s tweets downloaded so far
# getting tweets before 408069802045890559s
# ...1333s tweets downloaded so far
# getting tweets before 379315663652651007s
# ...1414s tweets downloaded so far
# getting tweets before 329958050163200002s
# ...1428s tweets downloaded so far
# getting tweets before 25732220695s
# ...1428s tweets downloaded so far
# Appended 4 of 20 timelines...
# getting tweets before 1235073109708824575s
# ...399s tweets downloaded so far
# getting tweets before 1229984830240067583s
# ...599s tweets downloaded so far
# getting tweets before 1224583412222066689s
# ...799s tweets downloaded so far
# getting tweets before 1218312117415079936s
# ...998s tweets downloaded so far
# getting tweets before 1210344439283101695s
# ...1197s tweets downloaded so far
# getting tweets before 1201305470926868479s
# ...1397s tweets downloaded so far
# getting tweets before 1194651631805030399s
# ...1591s tweets downloaded so far
# getting tweets before 1186836050565570559s
# ...1788s tweets downloaded so far
# getting tweets before 1178825774339633152s
# ...1982s tweets downloaded so far
# getting tweets before 1174883658878074879s
# ...2172s tweets downloaded so far
# getting tweets before 1167820395489030143s
# ...2356s tweets downloaded so far
# getting tweets before 1161091328014336000s
# ...2553s tweets downloaded so far
# getting tweets before 1157350003066564607s
# ...2743s tweets downloaded so far
# getting tweets before 1151642310687354879s
# ...2933s tweets downloaded so far
# getting tweets before 1140747591958667265s
# ...3122s tweets downloaded so far
# getting tweets before 1131971460342304767s
# ...3161s tweets downloaded so far
# getting tweets before 1130629441246285823s
# ...3161s tweets downloaded so far
# Appended 5 of 20 timelines...
# getting tweets before 774562930461401087s
# ...117s tweets downloaded so far
# Appended 6 of 20 timelines...
# getting tweets before 1237792905126912006s
# ...391s tweets downloaded so far
# getting tweets before 1236392989095673857s
# ...588s tweets downloaded so far
# getting tweets before 1235690188346621957s
# ...787s tweets downloaded so far
# getting tweets before 1234208575075110914s
# ...986s tweets downloaded so far
# getting tweets before 1230545171697274884s
# ...1184s tweets downloaded so far
# getting tweets before 1228386976992288768s
# ...1382s tweets downloaded so far
# getting tweets before 1225540035858006020s
# ...1580s tweets downloaded so far
# getting tweets before 1222573053378531329s
# ...1778s tweets downloaded so far
# getting tweets before 1216337392551985153s
# ...1974s tweets downloaded so far
# getting tweets before 1208472413693833215s
# ...2172s tweets downloaded so far
# getting tweets before 1200110748875116543s
# ...2371s tweets downloaded so far
# getting tweets before 1187511281236041730s
# ...2568s tweets downloaded so far
# getting tweets before 1174938294603247615s
# ...2764s tweets downloaded so far
# getting tweets before 1169462700897816576s
# ...2961s tweets downloaded so far
# getting tweets before 1163990764508131328s
# ...3155s tweets downloaded so far
# getting tweets before 1159555234701537279s
# ...3160s tweets downloaded so far
# getting tweets before 1159541611438706693s
# ...3160s tweets downloaded so far
# Appended 7 of 20 timelines...
# getting tweets before 982463735578218495s
# ...174s tweets downloaded so far
# Appended 8 of 20 timelines...
# getting tweets before 471660055721689088s
# ...194s tweets downloaded so far
# Appended 9 of 20 timelines...
# Rate limit reached. Sleeping for: 839
# getting tweets before 1076176627611004927s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-4d892ec57bf1> in <module>
#       1 for idx, user_id in enumerate(list_segment):
#       2     try:
# ----> 3         favorites.append(user_favorites(user_id))
#       4         print('Appended {} of {} timelines...'.format(idx+1, len(list_segment)))
#       5     except tweepy.TweepError:
#
# <ipython-input-2-9ac1c44b1a97> in user_favorites(user_id)
#      72
#      73             # all subsequent requests use the max_id param to prevent duplicates
# ---> 74             favorites = api.favorites(user_id=user_id, count=200, max_id=oldest)
#      75
#      76             favorite_tweets.extend(favorites)
#
# /opt/venv/lib/python3.7/site-packages/tweepy/binder.py in _call(*args, **kwargs)
#     248                 return method
#     249             else:
# --> 250                 return method.execute()
#     251         finally:
#     252             method.session.close()
#
# /opt/venv/lib/python3.7/site-packages/tweepy/binder.py in execute(self)
#     160                                     if self.wait_on_rate_limit_notify:
#     161                                         log.warning("Rate limit reached. Sleeping for: %d" % sleep_time)
# --> 162                                     time.sleep(sleep_time + 5)  # sleep for few extra sec
#     163
#     164                 # if self.wait_on_rate_limit and self._reset_time is not None and \
#
# KeyboardInterrupt:

# %%
for idx, user_id in enumerate(list_segment):
    try:
        profiles.append(user_profile(user_id))
        print('Appended {} of {} timelines...'.format(idx+1, len(list_segment)))
    except tweepy.TweepError:
        print("Failed to run the command on that user, Skipping...")

with open(f'profiles._{stop}json', 'w') as fout:
    json.dump(profiles, fout)
# Out:
# Failed to run the command on that user, Skipping...
# Rate limit reached. Sleeping for: 187
# Failed to run the command on that user, Skipping...
# Appended 3 of 134 timelines...
# Appended 4 of 134 timelines...
# Appended 5 of 134 timelines...
# Appended 6 of 134 timelines...
# Appended 7 of 134 timelines...
# Appended 8 of 134 timelines...
# Rate limit reached. Sleeping for: 894
# Appended 9 of 134 timelines...
# Failed to run the command on that user, Skipping...
# Appended 11 of 134 timelines...
# Appended 12 of 134 timelines...
# Failed to run the command on that user, Skipping...
# Appended 14 of 134 timelines...
# Appended 15 of 134 timelines...
# Appended 16 of 134 timelines...
# Rate limit reached. Sleeping for: 893
# Appended 17 of 134 timelines...
# Appended 18 of 134 timelines...
# Rate limit reached. Sleeping for: 896
# Failed to run the command on that user, Skipping...
# Appended 20 of 134 timelines...
# Failed to run the command on that user, Skipping...
# Appended 22 of 134 timelines...
# Appended 23 of 134 timelines...
# Appended 24 of 134 timelines...
# Appended 25 of 134 timelines...
# Appended 26 of 134 timelines...
# Appended 27 of 134 timelines...
# Rate limit reached. Sleeping for: 893
# Appended 28 of 134 timelines...
# Appended 29 of 134 timelines...
# Appended 30 of 134 timelines...
# Appended 31 of 134 timelines...
# Appended 32 of 134 timelines...
# Rate limit reached. Sleeping for: 895
# Failed to run the command on that user, Skipping...
# Appended 34 of 134 timelines...
# Appended 35 of 134 timelines...
# Failed to run the command on that user, Skipping...
# Appended 37 of 134 timelines...
# Appended 38 of 134 timelines...
# Appended 39 of 134 timelines...
# Appended 40 of 134 timelines...
# Appended 41 of 134 timelines...
# Failed to run the command on that user, Skipping...
# Appended 43 of 134 timelines...
# Rate limit reached. Sleeping for: 893
# Appended 44 of 134 timelines...
# Appended 45 of 134 timelines...
# Appended 46 of 134 timelines...
# Appended 47 of 134 timelines...
# Appended 48 of 134 timelines...
# Rate limit reached. Sleeping for: 895
# Failed to run the command on that user, Skipping...
# Appended 50 of 134 timelines...
# Appended 51 of 134 timelines...
# Failed to run the command on that user, Skipping...
# Appended 53 of 134 timelines...
# Failed to run the command on that user, Skipping...
# Appended 55 of 134 timelines...
# Failed to run the command on that user, Skipping...
# Appended 57 of 134 timelines...
# Appended 58 of 134 timelines...
# Appended 59 of 134 timelines...
# Appended 60 of 134 timelines...
# Rate limit reached. Sleeping for: 893
# Appended 61 of 134 timelines...
# Appended 62 of 134 timelines...
# Appended 63 of 134 timelines...
# Appended 64 of 134 timelines...
# Rate limit reached. Sleeping for: 895
# Failed to run the command on that user, Skipping...
# Appended 66 of 134 timelines...
# Appended 67 of 134 timelines...
# Appended 68 of 134 timelines...
# Appended 69 of 134 timelines...
# Appended 70 of 134 timelines...
# Appended 71 of 134 timelines...
# Rate limit reached. Sleeping for: 894
# Appended 72 of 134 timelines...
# Failed to run the command on that user, Skipping...
# Appended 74 of 134 timelines...
# Appended 75 of 134 timelines...
# Appended 76 of 134 timelines...
# Appended 77 of 134 timelines...
# Appended 78 of 134 timelines...
# Appended 79 of 134 timelines...
# Rate limit reached. Sleeping for: 893
# Appended 80 of 134 timelines...
# Appended 81 of 134 timelines...
# Appended 82 of 134 timelines...
# Appended 83 of 134 timelines...
# Appended 84 of 134 timelines...
# Rate limit reached. Sleeping for: 895
# Failed to run the command on that user, Skipping...
# Appended 86 of 134 timelines...
# Appended 87 of 134 timelines...
# Appended 88 of 134 timelines...
# Appended 89 of 134 timelines...
# Appended 90 of 134 timelines...
# Appended 91 of 134 timelines...
# Appended 92 of 134 timelines...
# Appended 93 of 134 timelines...
# Appended 94 of 134 timelines...
# Rate limit reached. Sleeping for: 893
# Appended 95 of 134 timelines...
# Appended 96 of 134 timelines...
# Appended 97 of 134 timelines...
# Appended 98 of 134 timelines...
# Appended 99 of 134 timelines...
# Appended 100 of 134 timelines...
# Rate limit reached. Sleeping for: 893
# Appended 101 of 134 timelines...
# Appended 102 of 134 timelines...
# Appended 103 of 134 timelines...
# Appended 104 of 134 timelines...
# Rate limit reached. Sleeping for: 894
# Appended 105 of 134 timelines...
# Appended 106 of 134 timelines...
# Rate limit reached. Sleeping for: 895
# Failed to run the command on that user, Skipping...
# Appended 108 of 134 timelines...
# Appended 109 of 134 timelines...
# Rate limit reached. Sleeping for: 896
# Failed to run the command on that user, Skipping...
# Appended 111 of 134 timelines...
# Appended 112 of 134 timelines...
# Appended 113 of 134 timelines...
# Appended 114 of 134 timelines...
# Rate limit reached. Sleeping for: 895
# Failed to run the command on that user, Skipping...
# Appended 116 of 134 timelines...
# Appended 117 of 134 timelines...
# Appended 118 of 134 timelines...
# Appended 119 of 134 timelines...
# Failed to run the command on that user, Skipping...
# Appended 121 of 134 timelines...
# Rate limit reached. Sleeping for: 894
# Appended 122 of 134 timelines...
# Appended 123 of 134 timelines...
# Appended 124 of 134 timelines...
# Appended 125 of 134 timelines...
# Appended 126 of 134 timelines...
# Appended 127 of 134 timelines...
# Appended 128 of 134 timelines...
# Rate limit reached. Sleeping for: 894
# Appended 129 of 134 timelines...
# Failed to run the command on that user, Skipping...
# Appended 131 of 134 timelines...
# Appended 132 of 134 timelines...
# Appended 133 of 134 timelines...
# Appended 134 of 134 timelines...

# %%
import pandas as pd

time_df = pd.DataFrame(timelines[0])

# %%
time_df
# Out:
#                       id                      created_at  screen_name  \
# 0    1236035178331541505  Fri Mar 06 21:05:25 +0000 2020  baka_brooks
# 1    1232902175753289728  Thu Feb 27 05:35:59 +0000 2020  baka_brooks
# 2    1232802180899332096  Wed Feb 26 22:58:38 +0000 2020  baka_brooks
# 3    1231010483345350656  Sat Feb 22 00:19:04 +0000 2020  baka_brooks
# 4    1230170439344742401  Wed Feb 19 16:41:02 +0000 2020  baka_brooks
# ..                   ...                             ...          ...
# 113  1004424236746719232  Wed Jun 06 18:06:13 +0000 2018  baka_brooks
# 114   999690774475243520  Thu May 24 16:37:08 +0000 2018  baka_brooks
# 115   997376577628336128  Fri May 18 07:21:21 +0000 2018  baka_brooks
# 116   996064345309134848  Mon May 14 16:27:00 +0000 2018  baka_brooks
# 117   996060287794008065  Mon May 14 16:10:53 +0000 2018  baka_brooks
#
#         user_id  in_reply_to_status_id in_reply_to_screen_name  \
# 0    2649540547                    NaN                    None
# 1    2649540547           1.232805e+18                 lolegra
# 2    2649540547           1.232699e+18               almeezyuh
# 3    2649540547           1.230929e+18                boykimba
# 4    2649540547           1.230170e+18                 backlon
# ..          ...                    ...                     ...
# 113  2649540547           1.004424e+18             speak_ezy23
# 114  2649540547                    NaN                    None
# 115  2649540547                    NaN                    None
# 116  2649540547           9.960626e+17              JuiceboxCA
# 117  2649540547           9.960158e+17                 evleaks
#
#      in_reply_to_user_id  favorite_count  retweet_count  \
# 0                    NaN               0              0
# 1           1.333492e+09               1              0
# 2           1.006084e+08               0              0
# 3           2.202389e+08               0              0
# 4           1.090141e+06               0              0
# ..                   ...             ...            ...
# 113         9.961986e+08               1              0
# 114                  NaN               1              0
# 115                  NaN               0          20915
# 116         1.990496e+07               1              0
# 117         7.882877e+08               0              0
#
#                                                   text
# 0    Understanding Power Analysis in AB Testing htt...
# 1                                     @lolegra hi + me
# 2                               @almeezyuh baka_brooks
# 3                                     @boykimba OK BTS
# 4    @backlon I am so ready for this review. Dieter...
# ..                                                 ...
# 113                    @speak_ezy23 GRADE A KOGIIIIIII
# 114  A1: Access to data is only going to be more an...
# 115  RT @Hejibits: I live for the anime opening tro...
# 116              @JuiceboxCA @RAGEgame YESYESYESYESYES
# 117  @evleaks Same processor too? Wow we really jus...
#
# [118 rows x 10 columns]
