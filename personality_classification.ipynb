# %%
from ibm_watson_creds import apikey
from ibm_watson import PersonalityInsightsV3
from ibm_cloud_sdk_core.authenticators import IAMAuthenticator

import json
import pandas as pd
import numpy as np
from collections import defaultdict
import pprint as pp

# %%
# set IBM Watson Credentials
url = 'https://api.us-south.personality-insights.watson.cloud.ibm.com/instances/bbb53899-1323-4424-a9c2-82e7a719c287'
version = '2020-01-08'

# %%
# set personality insights
authenticator = IAMAuthenticator(apikey)
personality_insights = PersonalityInsightsV3(
    version=version,
    authenticator=authenticator
)

personality_insights.set_service_url(url)

# %% [markdown]
# ## Apply IBM Watson Personality Insights API to full corpus of text per profile

# %%
# read in favorites dataframe (uncprocessed)
df = pd.read_pickle('favorites.pkl')

# %%
df.head(1)
# Out:
#    favorited_by_id                   id                      created_at  \
# 0       2649540547  1236533635290890240  Sun Mar 08 06:06:06 +0000 2020
#
#   screen_name    user_id  in_reply_to_status_id in_reply_to_screen_name  \
# 0         AOC  138203134           1.236524e+18                  nbcsnl
#
#    in_reply_to_user_id  favorite_count  retweet_count  \
# 0           28221296.0          115728           3550
#
#                            text
# 0  @nbcsnl ok this is legendary

# %%
# group tweets by user_id tweet was favorited by and concatenate all tweets into one string
alltweets_per_user = df.groupby('favorited_by_id')['text'].transform(lambda x: ', '.join(x)).drop_duplicates()

# %%
# create a dataframe mapping user_ids to their full text
ids = list(df.favorited_by_id.unique())

tweets_per_user = pd.DataFrame({'user_id': ids, 'all_tweets': alltweets_per_user}, columns=['user_id', 'all_tweets']).reset_index(drop=True)
tweets_per_user.head()
# Out:
#                user_id                                         all_tweets
# 0           2649540547  @nbcsnl ok this is legendary, 𝗙𝗹𝗶𝗽𝗽𝗲𝗱 𝘁𝗵𝗲 𝘀𝘄𝗶𝘁...
# 1  1094750013304029187  We in the Bay Area should do this too https://...
# 2  1235337664083222528  Crack SQL Interviews  https://t.co/AJzljKpV2a,...
# 3           1333491954  i used to wait for love before i loved back.\n...
# 4  1219308741369253894  @DishNation I ordered the TrackR that you prom...

# %%
def personality_profile(tweets):
    """
    Create personality profile using IBM Watson API given a corpus of tweets.
    ---
    :param tweets: String of concatenated tweets.
    :return: JSON object of the personality profile of the user with which the tweets correspond.
    """
    
    try:
        profile = personality_insights.profile(tweets, accept='application/json').get_result()
        return profile
    except:
        pass

# %% [markdown]
# ### Test using my own personality profile to structure output of full dataset

# %%
# run test on my profile
my_profile = personality_profile(tweets_per_user.iloc[0]['all_tweets'])
pp.pprint(my_profile['personality'])
# Out:
# [{'category': 'personality',
#   'children': [{'category': 'personality',
#                 'name': 'Adventurousness',
#                 'percentile': 0.5092574278504252,
#                 'significant': True,
#                 'trait_id': 'facet_adventurousness'},
#                {'category': 'personality',
#                 'name': 'Artistic interests',
#                 'percentile': 0.5546090668268516,
#                 'significant': True,
#                 'trait_id': 'facet_artistic_interests'},
#                {'category': 'personality',
#                 'name': 'Emotionality',
#                 'percentile': 0.4681742846520679,
#                 'significant': True,
#                 'trait_id': 'facet_emotionality'},
#                {'category': 'personality',
#                 'name': 'Imagination',
#                 'percentile': 0.7781376603492451,
#                 'significant': True,
#                 'trait_id': 'facet_imagination'},
#                {'category': 'personality',
#                 'name': 'Intellect',
#                 'percentile': 0.8925424227512277,
#                 'significant': True,
#                 'trait_id': 'facet_intellect'},
#                {'category': 'personality',
#                 'name': 'Authority-challenging',
#                 'percentile': 0.9385909133679127,
#                 'significant': True,
#                 'trait_id': 'facet_liberalism'}],
#   'name': 'Openness',
#   'percentile': 0.7302360141572732,
#   'significant': True,
#   'trait_id': 'big5_openness'},
#  {'category': 'personality',
#   'children': [{'category': 'personality',
#                 'name': 'Achievement striving',
#                 'percentile': 0.3092753303945954,
#                 'significant': True,
#                 'trait_id': 'facet_achievement_striving'},
#                {'category': 'personality',
#                 'name': 'Cautiousness',
#                 'percentile': 0.4460978867841803,
#                 'significant': True,
#                 'trait_id': 'facet_cautiousness'},
#                {'category': 'personality',
#                 'name': 'Dutifulness',
#                 'percentile': 0.393284156199746,
#                 'significant': True,
#                 'trait_id': 'facet_dutifulness'},
#                {'category': 'personality',
#                 'name': 'Orderliness',
#                 'percentile': 0.14003723234351023,
#                 'significant': True,
#                 'trait_id': 'facet_orderliness'},
#                {'category': 'personality',
#                 'name': 'Self-discipline',
#                 'percentile': 0.16038002679944413,
#                 'significant': True,
#                 'trait_id': 'facet_self_discipline'},
#                {'category': 'personality',
#                 'name': 'Self-efficacy',
#                 'percentile': 0.289040364965959,
#                 'significant': True,
#                 'trait_id': 'facet_self_efficacy'}],
#   'name': 'Conscientiousness',
#   'percentile': 0.33493319494251395,
#   'significant': True,
#   'trait_id': 'big5_conscientiousness'},
#  {'category': 'personality',
#   'children': [{'category': 'personality',
#                 'name': 'Activity level',
#                 'percentile': 0.5150838303881349,
#                 'significant': True,
#                 'trait_id': 'facet_activity_level'},
#                {'category': 'personality',
#                 'name': 'Assertiveness',
#                 'percentile': 0.4658693167392055,
#                 'significant': True,
#                 'trait_id': 'facet_assertiveness'},
#                {'category': 'personality',
#                 'name': 'Cheerfulness',
#                 'percentile': 0.14219688902416333,
#                 'significant': True,
#                 'trait_id': 'facet_cheerfulness'},
#                {'category': 'personality',
#                 'name': 'Excitement-seeking',
#                 'percentile': 0.42469755701125267,
#                 'significant': True,
#                 'trait_id': 'facet_excitement_seeking'},
#                {'category': 'personality',
#                 'name': 'Outgoing',
#                 'percentile': 0.19904979597960204,
#                 'significant': True,
#                 'trait_id': 'facet_friendliness'},
#                {'category': 'personality',
#                 'name': 'Gregariousness',
#                 'percentile': 0.20796720515284162,
#                 'significant': True,
#                 'trait_id': 'facet_gregariousness'}],
#   'name': 'Extraversion',
#   'percentile': 0.4116283016212918,
#   'significant': True,
#   'trait_id': 'big5_extraversion'},
#  {'category': 'personality',
#   'children': [{'category': 'personality',
#                 'name': 'Altruism',
#                 'percentile': 0.3361088687560558,
#                 'significant': True,
#                 'trait_id': 'facet_altruism'},
#                {'category': 'personality',
#                 'name': 'Cooperation',
#                 'percentile': 0.3288682177691229,
#                 'significant': True,
#                 'trait_id': 'facet_cooperation'},
#                {'category': 'personality',
#                 'name': 'Modesty',
#                 'percentile': 0.25084995499312845,
#                 'significant': True,
#                 'trait_id': 'facet_modesty'},
#                {'category': 'personality',
#                 'name': 'Uncompromising',
#                 'percentile': 0.24625286556506615,
#                 'significant': True,
#                 'trait_id': 'facet_morality'},
#                {'category': 'personality',
#                 'name': 'Sympathy',
#                 'percentile': 0.4420924380618306,
#                 'significant': True,
#                 'trait_id': 'facet_sympathy'},
#                {'category': 'personality',
#                 'name': 'Trust',
#                 'percentile': 0.48507876427396934,
#                 'significant': True,
#                 'trait_id': 'facet_trust'}],
#   'name': 'Agreeableness',
#   'percentile': 0.10601469213298487,
#   'significant': True,
#   'trait_id': 'big5_agreeableness'},
#  {'category': 'personality',
#   'children': [{'category': 'personality',
#                 'name': 'Fiery',
#                 'percentile': 0.7537591970651667,
#                 'significant': True,
#                 'trait_id': 'facet_anger'},
#                {'category': 'personality',
#                 'name': 'Prone to worry',
#                 'percentile': 0.6912793459100934,
#                 'significant': True,
#                 'trait_id': 'facet_anxiety'},
#                {'category': 'personality',
#                 'name': 'Melancholy',
#                 'percentile': 0.8251226289094614,
#                 'significant': True,
#                 'trait_id': 'facet_depression'},
#                {'category': 'personality',
#                 'name': 'Immoderation',
#                 'percentile': 0.6892122034331108,
#                 'significant': True,
#                 'trait_id': 'facet_immoderation'},
#                {'category': 'personality',
#                 'name': 'Self-consciousness',
#                 'percentile': 0.8297648264978092,
#                 'significant': True,
#                 'trait_id': 'facet_self_consciousness'},
#                {'category': 'personality',
#                 'name': 'Susceptible to stress',
#                 'percentile': 0.7613051566260833,
#                 'significant': True,
#                 'trait_id': 'facet_vulnerability'}],
#   'name': 'Emotional range',
#   'percentile': 0.5527239153490785,
#   'significant': True,
#   'trait_id': 'big5_neuroticism'}]

# %% [markdown]
# ### Loop through all user profiles and create personality profiles

# %%
all_profiles = []
for tweet in tweets_per_user.all_tweets:
    profile = personality_profile(tweet)
    all_profiles.append(profile)
# Out:
# ERROR:root:The number of words 24 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 24 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: 8ea0c48bd8578d69b13499daa63a64e4
# ERROR:root:The number of words 14 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 14 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: 2e4f2c8369cb578c5b9f9eaa87f920c2
# ERROR:root:The number of words 36 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 36 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: 4aed263751ffd1058d774a4abb4b06bf
# ERROR:root:The number of words 0 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 0 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: 28948ec9faaa37aa8db3aa76c2c6bbf8
# ERROR:root:The number of words 42 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 42 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: 620f6a49662320d1eaada01f42d7d257
# ERROR:root:The number of words 50 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 50 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: 94cde8e7ae52ff0a7b60e069839ed9a3
# ERROR:root:The number of words 4 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 4 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: af15dd4222d594c901736056819db5ab
# ERROR:root:The number of words 12 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 12 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: ee69b4755bd5aa352dcdc48f956bce2f
# ERROR:root:The number of words 62 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 62 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: 45bc205e6b2d10526bd1c7fce764069a
# ERROR:root:The number of words 57 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 57 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: 2f2607321fd93716376ef9b12b380c6b
# ERROR:root:The number of words 60 is less than the minimum number of words required for analysis: 100
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/ibm_cloud_sdk_core/base_service.py", line 229, in send
#     response.status_code, error_message, http_response=response)
# ibm_cloud_sdk_core.api_exception.ApiException: Error: The number of words 60 is less than the minimum number of words required for analysis: 100, Code: 400 , X-global-transaction-id: f326bdfcda7b3d9f5cab5415b3c0eea8

# %% [markdown]
# ### Extract the big 5 personality type percerntiles from each user

# %%
# extract personality types from full profiles and create list of dictionaries for each user
personality_percentiles = []
for traits in all_profiles:
    personality_vector = defaultdict(float)
    try:
        for idx, personality_type in enumerate(traits['personality']):
            personality_vector[personality_type['name']] = personality_type['percentile']
    except TypeError:
        for personality_type in ['Openness', 'Conscientiousness', 'Extraversion', 'Agreeableness', 'Emotional range']:
            personality_vector[personality_type] = np.nan
    personality_percentiles.append(personality_vector)

# %%
# create a dataframe from the extracted personality types
personality_df = pd.DataFrame(personality_percentiles)
personality_df.head()
# Out:
#    Openness  Conscientiousness  Extraversion  Agreeableness  Emotional range
# 0  0.730236           0.334933      0.411628       0.106015         0.552724
# 1  0.906036           0.550105      0.648426       0.297694         0.500949
# 2  0.708852           0.768717      0.294999       0.154030         0.112169
# 3  0.518856           0.069776      0.637403       0.241616         0.757079
# 4  0.466320           0.706029      0.187577       0.058168         0.317718

# %%
# concatentate the personality types to the original dataframe to map personalities to users
user_personalities = pd.concat([tweets_per_user, personality_df], axis=1)

# %%
# export dataframe to pickle file
user_personalities.to_pickle('personalities.pkl')
